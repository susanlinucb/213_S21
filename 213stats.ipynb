# %% [markdown]
# Let's read in the data -- this data has already been normalized, from last week's work!
#
# Notice that the way to look at the "head" of a dataframe is different in R...

# %%
df = read.csv('./213_data_normalized.csv')
head(df)
# Out:
#   X Speaker Repetition Order Word   variable value        measurement time
# 1 0 Ben     1          1     boot   oaf_20   -0.040890030 oaf         20
# 2 1 Ben     1          2     birm   oaf_20   -0.023103800 oaf         20
# 3 2 Ben     1          3     bait   oaf_20    0.211848002 oaf         20
# 4 3 Ben     1          4     bite   oaf_20    0.008302278 oaf         20
# 5 4 Ben     1          5     beat   oaf_20    0.300334307 oaf         20
# 6 5 Ben     1          6     bought oaf_20    0.138955231 oaf         20
#   Nasal Height1 Height2 R
# 1 False high    high    False
# 2 True  high    high    True
# 3 False mid     high    False
# 4 False low     high    False
# 5 False high    high    False
# 6 False low     low     False

# %% [markdown]
# R has a nice subsetting function!

# %%
subset(df,df$measurement=='oaf')  # The $ symbol accesses variables
# Out:
#        X      Speaker Repetition Order  Word   variable value
# 1       0     Ben     1           1     boot   oaf_20   -0.040890030
# 2       1     Ben     1           2     birm   oaf_20   -0.023103800
# 3       2     Ben     1           3     bait   oaf_20    0.211848002
# 4       3     Ben     1           4     bite   oaf_20    0.008302278
# 5       4     Ben     1           5     beat   oaf_20    0.300334307
# 6       5     Ben     1           6     bought oaf_20    0.138955231
# 7       6     Ben     1           7     Bert   oaf_20    0.380676839
# 8       7     Ben     1           8     bout   oaf_20   -0.162573794
# 9       8     Ben     1           9     bin    oaf_20    0.068628224
# 10      9     Ben     1          10     bound  oaf_20   -0.138164720
# 11     10     Ben     1          11     boon   oaf_20    0.335876200
# 12     11     Ben     1          12     boing  oaf_20    0.822099415
# 13     12     Ben     1          13     but    oaf_20    1.083121767
# 14     13     Ben     1          14     born   oaf_20    0.434470956
# 15     14     Ben     1          15     bort   oaf_20    0.650539566
# 16     15     Ben     1          16     bun    oaf_20    0.540535942
# 17     16     Ben     1          17     boit   oaf_20    0.403928229
# 18     17     Ben     1          18     Ben    oaf_20   -0.085790690
# 19     18     Ben     1          19     barn   oaf_20    0.278976503
# 20     19     Ben     1          20     bet    oaf_20    0.177776821
# 21     20     Ben     1          21     bot    oaf_20    0.212025257
# 22     21     Ben     1          22     Bart   oaf_20    0.608698363
# 23     22     Ben     1          23     bat    oaf_20   -0.209371316
# 24     23     Ben     1          24     bean   oaf_20    0.448983493
# 25     24     Ben     1          25     bone   oaf_20    0.412688778
# 26     25     Ben     1          26     bit    oaf_20    0.908711373
# 27     26     Ben     1          27     ban    oaf_20    0.420534941
# 28     27     Ben     1          28     boat   oaf_20    0.412673222
# 29     28     Ben     1          29     bomb   oaf_20   -0.020974692
# 30     29     Ben     1          30     bind   oaf_20   -0.016663669
# <U+22EE> <U+22EE> <U+22EE> <U+22EE>   <U+22EE> <U+22EE> <U+22EE> <U+22EE>
# 4325   4324   Cynthia 1           2     birm   oaf_80   0.4173304
# 4326   4325   Cynthia 1           3     bait   oaf_80   0.3983294
# 4327   4326   Cynthia 1           4     bite   oaf_80   0.3845276
# 4328   4327   Cynthia 1           5     beat   oaf_80   0.3890549
# 4329   4328   Cynthia 1           6     bought oaf_80   0.3931097
# 4330   4329   Cynthia 1           7     Bert   oaf_80   0.4055828
# 4331   4330   Cynthia 1           8     bout   oaf_80   0.3996916
# 4332   4331   Cynthia 1           9     bin    oaf_80   0.3776309
# 4333   4332   Cynthia 1          10     bound  oaf_80   0.3924420
# 4334   4333   Cynthia 1          11     boon   oaf_80   0.5271630
# 4335   4334   Cynthia 1          12     boing  oaf_80   0.3886086
# 4336   4335   Cynthia 1          13     but    oaf_80   0.4158125
# 4337   4336   Cynthia 1          14     born   oaf_80   0.3609452
# 4338   4337   Cynthia 1          15     bort   oaf_80   0.3948030
# 4339   4338   Cynthia 1          16     bun    oaf_80   0.4133996
# 4340   4339   Cynthia 1          17     boit   oaf_80   0.3958967
# 4341   4340   Cynthia 1          18     Ben    oaf_80   0.3996763
# 4342   4341   Cynthia 1          19     barn   oaf_80   0.3910306
# 4343   4342   Cynthia 1          20     bet    oaf_80   0.4001314
# 4344   4343   Cynthia 1          21     bot    oaf_80   0.3852092
# 4345   4344   Cynthia 1          22     Bart   oaf_80   0.3856819
# 4346   4345   Cynthia 1          23     bat    oaf_80   0.3850530
# 4347   4346   Cynthia 1          24     bean   oaf_80   0.3836745
# 4348   4347   Cynthia 1          25     bone   oaf_80   0.3930546
# 4349   4348   Cynthia 1          26     bit    oaf_80   0.4011768
# 4350   4349   Cynthia 1          27     ban    oaf_80   0.5498353
# 4351   4350   Cynthia 1          28     boat   oaf_80   0.3826360
# 4352   4351   Cynthia 1          29     bomb   oaf_80   0.3779911
# 4353   4352   Cynthia 1          30     bind   oaf_80   0.4189367
# 4354   4353   Cynthia 1          31     bane   oaf_80   0.4016329
#        measurement time   Nasal  Height1 Height2 R
# 1      oaf         20     False  high    high    False
# 2      oaf         20     True   high    high    True
# 3      oaf         20     False  mid     high    False
# 4      oaf         20     False  low     high    False
# 5      oaf         20     False  high    high    False
# 6      oaf         20     False  low     low     False
# 7      oaf         20     False  mid     mid     True
# 8      oaf         20     False  low     high    False
# 9      oaf         20     True   high    high    False
# 10     oaf         20     True   low     high    False
# 11     oaf         20     True   high    high    False
# 12     oaf         20     True   low     high    False
# 13     oaf         20     False  mid     mid     False
# 14     oaf         20     True   mid     mid     True
# 15     oaf         20     False  mid     mid     True
# 16     oaf         20     True   mid     mid     False
# 17     oaf         20     False  low     high    False
# 18     oaf         20     True   mid     mid     False
# 19     oaf         20     True   low     low     True
# 20     oaf         20     False  mid     mid     False
# 21     oaf         20     False  low     low     False
# 22     oaf         20     False  low     low     True
# 23     oaf         20     False  low     low     False
# 24     oaf         20     True   high    high    False
# 25     oaf         20     True   mid     high    False
# 26     oaf         20     False  high    high    False
# 27     oaf         20     True   low     low     False
# 28     oaf         20     False  mid     high    False
# 29     oaf         20     True   low     low     False
# 30     oaf         20     True   low     high    False
# <U+22EE> <U+22EE>    <U+22EE> <U+22EE> <U+22EE> <U+22EE> <U+22EE>
# 4325   oaf         80     True   high    high    True
# 4326   oaf         80     False  mid     high    False
# 4327   oaf         80     False  low     high    False
# 4328   oaf         80     False  high    high    False
# 4329   oaf         80     False  low     low     False
# 4330   oaf         80     False  mid     mid     True
# 4331   oaf         80     False  low     high    False
# 4332   oaf         80     True   high    high    False
# 4333   oaf         80     True   low     high    False
# 4334   oaf         80     True   high    high    False
# 4335   oaf         80     True   low     high    False
# 4336   oaf         80     False  mid     mid     False
# 4337   oaf         80     True   mid     mid     True
# 4338   oaf         80     False  mid     mid     True
# 4339   oaf         80     True   mid     mid     False
# 4340   oaf         80     False  low     high    False
# 4341   oaf         80     True   mid     mid     False
# 4342   oaf         80     True   low     low     True
# 4343   oaf         80     False  mid     mid     False
# 4344   oaf         80     False  low     low     False
# 4345   oaf         80     False  low     low     True
# 4346   oaf         80     False  low     low     False
# 4347   oaf         80     True   high    high    False
# 4348   oaf         80     True   mid     high    False
# 4349   oaf         80     False  high    high    False
# 4350   oaf         80     True   low     low     False
# 4351   oaf         80     False  mid     high    False
# 4352   oaf         80     True   low     low     False
# 4353   oaf         80     True   low     high    False
# 4354   oaf         80     True   mid     high    False

# %% [markdown]
# R's generic `plot` function is a "smart" function, meaning what it displays depends on the variables you give it. By default, if you plot two numeric values against each other, you'll get a scatterplot:

# %%
plot(value~time,data=df)
# Out:
# plot without title

# %% [markdown]
# But a scatterplot is a pretty terrible way to visualize this data, beacuse the time values 20/50/80 are not really a continuous variable. We can force the dataframe to treat that variable as a discrete variable instead. Now, the plot function will give us a boxplot instead!

# %%
df$time = as.factor(df$time)
plot(value~time,data=df)
# Out:
# plot without title

# %% [markdown]
# What if we give it two discrete variables?

# %%
plot(Height2~Height1,data=df)
# Out:
# Plot with title ""

# %% [markdown]
# What if we want to make more complex plots? A simple package is the `lattice` package. A more complex package is `ggplot`, but (in my opinion) you are better off using `seaborn` in python if you need `ggplot`'s complexity.

# %%
library(lattice)
bwplot(value~time|measurement,data=df)
bwplot(value~Nasal|time*measurement,data=df)
# Out:
# plot without title
# plot without title

# %% [markdown]
# Ok but that's not what we moved to R for... we want to try to do some stats!

# %%
summary(aov(value~Nasal, data=subset(df,df$measurement=='naf' & df$time==80)))
# Out:
#              Df Sum Sq Mean Sq F value   Pr(>F)
# Nasal         1  13.66  13.661   71.12 2.37e-16 ***
# Residuals   619 118.89   0.192
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# 1 observation deleted due to missingness

# %%
summary(aov(value~Nasal+Error(df$Repetition), data=subset(df,df$measurement=='naf' & df$time==80)))
# Out:
# Error in model.frame.default(formula = value ~ df$Repetition, data = subset(df, : variable lengths differ (found for 'df$Repetition')
# Traceback:
#
# 1. summary(aov(value ~ Nasal + Error(df$Repetition), data = subset(df,
#  .     df$measurement == "naf" & df$time == 80)))
# 2. aov(value ~ Nasal + Error(df$Repetition), data = subset(df, df$measurement ==
#  .     "naf" & df$time == 80))
# 3. eval(ecall, parent.frame())
# 4. eval(ecall, parent.frame())
# 5. stats::lm(formula = value ~ df$Repetition, data = subset(df,
#  .     df$measurement == "naf" & df$time == 80), singular.ok = TRUE,
#  .     method = "qr", qr = TRUE)
# 6. eval(mf, parent.frame())
# 7. eval(mf, parent.frame())
# 8. stats::model.frame(formula = value ~ df$Repetition, data = subset(df,
#  .     df$measurement == "naf" & df$time == 80), drop.unused.levels = TRUE)
# 9. model.frame.default(formula = value ~ df$Repetition, data = subset(df,
#  .     df$measurement == "naf" & df$time == 80), drop.unused.levels = TRUE)

# %%
library(lme4)
# Out:
# Loading required package: Matrix

# %% [markdown]
# Let's do something with the nasal context first, just to confirm that things "look good". In the context of a nasal coda, we should expect nasal airflow (measurement=naf) to be higher than when the vowels are not in the context of a nasal coda. For simplicity's sake, let's look only at the data at the ends of the vowel (time=80)

# %%
summary(lmer(value~Nasal+(1+Nasal|Speaker)+(1+Nasal|Repetition),data=subset(df,df$measurement=='naf' & df$time==80)))
# Out:
# Linear mixed model fit by REML ['lmerMod']
# Formula: value ~ Nasal + (1 + Nasal | Speaker) + (1 + Nasal | Repetition)
#    Data: subset(df, df$measurement == "naf" & df$time == 80)
#
# REML criterion at convergence: 419.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.5197 -0.5616  0.0058  0.3185  7.6968
#
# Random effects:
#  Groups     Name        Variance Std.Dev. Corr
#  Speaker    (Intercept) 0.036490 0.19102
#             NasalTrue   0.045243 0.21270  0.59
#  Repetition (Intercept) 0.003999 0.06324
#             NasalTrue   0.052202 0.22848  -0.67
#  Residual               0.106123 0.32577
# Number of obs: 621, groups:  Speaker, 5; Repetition, 5
#
# Fixed effects:
#             Estimate Std. Error t value
# (Intercept)  0.29857    0.09245   3.229
# NasalTrue    0.29471    0.14295   2.062
#
# Correlation of Fixed Effects:
#           (Intr)
# NasalTrue 0.185

# %% [markdown]
# But you might be concerned that there is no p-value. If you require p-values, you can use the library lmerTest or a different method.

# %%
library(lmerTest)
# Out:
# Attaching package: 'lmerTest'
#
# The following object is masked from 'package:lme4':
#
#     lmer
#
# The following object is masked from 'package:stats':
#
#     step

# %%
summary(lmer(value~Nasal+(1+Nasal|Speaker)+(1+Nasal|Repetition),data=subset(df,df$measurement=='naf' & df$time==80)))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: value ~ Nasal + (1 + Nasal | Speaker) + (1 + Nasal | Repetition)
#    Data: subset(df, df$measurement == "naf" & df$time == 80)
#
# REML criterion at convergence: 419.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.5197 -0.5616  0.0058  0.3185  7.6968
#
# Random effects:
#  Groups     Name        Variance Std.Dev. Corr
#  Speaker    (Intercept) 0.036490 0.19102
#             NasalTrue   0.045243 0.21270  0.59
#  Repetition (Intercept) 0.003999 0.06324
#             NasalTrue   0.052202 0.22848  -0.67
#  Residual               0.106123 0.32577
# Number of obs: 621, groups:  Speaker, 5; Repetition, 5
#
# Fixed effects:
#             Estimate Std. Error      df t value Pr(>|t|)
# (Intercept)  0.29857    0.09245 4.92203   3.229   0.0237 *
# NasalTrue    0.29471    0.14295 7.51695   2.062   0.0754 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#           (Intr)
# NasalTrue 0.185

# %% [markdown]
# Now let's ask another question:

# %%
summary(lmer(value~Height1+(1+Height1|Speaker)+(1|Repetition),data=subset(df,df$measurement=='oaf' & df$time==20)))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: value ~ Height1 + (1 + Height1 | Speaker) + (1 | Repetition)
#    Data: subset(df, df$measurement == "oaf" & df$time == 20)
#
# REML criterion at convergence: 499.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.4728 -0.5988 -0.0209  0.5684  4.0417
#
# Random effects:
#  Groups     Name        Variance  Std.Dev. Corr
#  Speaker    (Intercept) 9.764e-02 0.312478
#             Height1low  4.606e-06 0.002146 1.00
#             Height1mid  3.470e-04 0.018628 1.00 1.00
#  Repetition (Intercept) 7.518e-03 0.086704
#  Residual               1.228e-01 0.350426
# Number of obs: 621, groups:  Speaker, 5; Repetition, 5
#
# Fixed effects:
#              Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)   0.58277    0.14851   4.51515   3.924   0.0136 *
# Height1low   -0.17585    0.03702 492.88712  -4.750 2.67e-06 ***
# Height1mid   -0.03777    0.03910  36.35620  -0.966   0.3404
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#            (Intr) Hght1l
# Height1low -0.140
# Height1mid  0.046  0.630
